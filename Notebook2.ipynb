# %% [markdown]
# # Random Forest Regression

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('tourism_data_500_points.csv')
df
# Out:
#                                Date                        Location
# 0     2019-01-01 00:00:00.000000000                Kimberley Museum  \
# 1     2019-01-01 00:00:00.000000000                 McGregor Museum
# 2     2019-01-01 00:00:00.000000000   William Humphreys Art Gallery
# 3     2019-01-01 00:00:00.000000000       Magersfontein Battlefield
# 4     2019-01-01 00:00:00.000000000  Ghost Tours & Historical Walks
# ...                             ...                             ...
# 2495  2023-01-01 00:00:00.000000000                Kimberley Museum
# 2496  2023-01-01 00:00:00.000000000                 McGregor Museum
# 2497  2023-01-01 00:00:00.000000000   William Humphreys Art Gallery
# 2498  2023-01-01 00:00:00.000000000       Magersfontein Battlefield
# 2499  2023-01-01 00:00:00.000000000  Ghost Tours & Historical Walks
#
#       Number_of_Visitors
# 0                   3970
# 1                   4278
# 2                   4354
# 3                   5956
# 4                   5450
# ...                  ...
# 2495                3405
# 2496                5090
# 2497                4292
# 2498                5294
# 2499                1135
#
# [2500 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Date                  0
# Location              0
# Number_of_Visitors    0
# dtype: int64

# %%
df['Location'].unique()
# Out:
# array(['Kimberley Museum', 'McGregor Museum',
#        'William Humphreys Art Gallery', 'Magersfontein Battlefield',
#        'Ghost Tours & Historical Walks'], dtype=object)

# %%
col = ['Location', 'Date']

# %%
df_encoder = pd.get_dummies(df, columns = col)
df_encoder
# Out:
#       Number_of_Visitors  Location_Ghost Tours & Historical Walks
# 0                   3970                                    False  \
# 1                   4278                                    False
# 2                   4354                                    False
# 3                   5956                                    False
# 4                   5450                                     True
# ...                  ...                                      ...
# 2495                3405                                    False
# 2496                5090                                    False
# 2497                4292                                    False
# 2498                5294                                    False
# 2499                1135                                     True
#
#       Location_Kimberley Museum  Location_Magersfontein Battlefield
# 0                          True                               False  \
# 1                         False                               False
# 2                         False                               False
# 3                         False                                True
# 4                         False                               False
# ...                         ...                                 ...
# 2495                       True                               False
# 2496                      False                               False
# 2497                      False                               False
# 2498                      False                                True
# 2499                      False                               False
#
#       Location_McGregor Museum  Location_William Humphreys Art Gallery
# 0                        False                                   False  \
# 1                         True                                   False
# 2                        False                                    True
# 3                        False                                   False
# 4                        False                                   False
# ...                        ...                                     ...
# 2495                     False                                   False
# 2496                      True                                   False
# 2497                     False                                    True
# 2498                     False                                   False
# 2499                     False                                   False
#
#       Date_2019-01-01 00:00:00.000000000  Date_2019-01-03 22:16:06.733466933
# 0                                   True                               False  \
# 1                                   True                               False
# 2                                   True                               False
# 3                                   True                               False
# 4                                   True                               False
# ...                                  ...                                 ...
# 2495                               False                               False
# 2496                               False                               False
# 2497                               False                               False
# 2498                               False                               False
# 2499                               False                               False
#
#       Date_2019-01-06 20:32:13.466933867  Date_2019-01-09 18:48:20.200400801
# 0                                  False                               False  \
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# ...                                  ...                                 ...
# 2495                               False                               False
# 2496                               False                               False
# 2497                               False                               False
# 2498                               False                               False
# 2499                               False                               False
#
#       ...  Date_2022-12-05 15:34:59.398797600
# 0     ...                               False  \
# 1     ...                               False
# 2     ...                               False
# 3     ...                               False
# 4     ...                               False
# ...   ...                                 ...
# 2495  ...                               False
# 2496  ...                               False
# 2497  ...                               False
# 2498  ...                               False
# 2499  ...                               False
#
#       Date_2022-12-08 13:51:06.132264528  Date_2022-12-11 12:07:12.865731472
# 0                                  False                               False  \
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# ...                                  ...                                 ...
# 2495                               False                               False
# 2496                               False                               False
# 2497                               False                               False
# 2498                               False                               False
# 2499                               False                               False
#
#       Date_2022-12-14 10:23:19.599198400  Date_2022-12-17 08:39:26.332665328
# 0                                  False                               False  \
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# ...                                  ...                                 ...
# 2495                               False                               False
# 2496                               False                               False
# 2497                               False                               False
# 2498                               False                               False
# 2499                               False                               False
#
#       Date_2022-12-20 06:55:33.066132272  Date_2022-12-23 05:11:39.799599200
# 0                                  False                               False  \
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# ...                                  ...                                 ...
# 2495                               False                               False
# 2496                               False                               False
# 2497                               False                               False
# 2498                               False                               False
# 2499                               False                               False
#
#       Date_2022-12-26 03:27:46.533066128  Date_2022-12-29 01:43:53.266533072
# 0                                  False                               False  \
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# ...                                  ...                                 ...
# 2495                               False                               False
# 2496                               False                               False
# 2497                               False                               False
# 2498                               False                               False
# 2499                               False                               False
#
#       Date_2023-01-01 00:00:00.000000000
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ...                                  ...
# 2495                                True
# 2496                                True
# 2497                                True
# 2498                                True
# 2499                                True
#
# [2500 rows x 506 columns]

# %%
X = df_encoder.drop('Number_of_Visitors', axis = 1)
y = df_encoder['Number_of_Visitors']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
model = RandomForestRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
r2_score = metrics.r2_score(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
mae = metrics.mean_absolute_error(y_test, y_pred)

# %%
print("R2 Score: ", r2_score)
print("MSE: ", mse)
print("MAE: ", mae)
# Out:
# R2 Score:  -0.24038533665869166
# MSE:  2781922.9552342
# MAE:  1310.6983400000001

# %%
with open('results2.txt', 'w') as f:
    f.write(f"R2 score: {r2_score}\n")
    f.write(f"Mean Squared Error: {mse}\n")
    f.write(f"Mean Absolute Error: {mae}\n")
